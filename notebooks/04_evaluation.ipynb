# %% [markdown]
# Baseline Performance — Linear Regression
#
# The initial Linear Regression model produced a very low
# 𝑅
# 2
# R
# 2
#  score (~0.04). This indicates that a simple linear relationship was insufficient to explain price variability, largely due to the strong skewness and presence of extreme outliers in the target variable.

# %% [markdown]
# Baseline Performance — Linear Regression
#
# The initial Linear Regression model produced a very low
# 𝑅
# 2
# R
# 2
#  score (~0.04). This indicates that a simple linear relationship was insufficient to explain price variability, largely due to the strong skewness and presence of extreme outliers in the target variable.

# %% [markdown]
# Random Forest Model Performance
#
# The final Random Forest model achieved the best performance with an
# 𝑅
# 2
# R
# 2
#  score of 0.2175. This improvement suggests that the relationship between listing features and price is non-linear, which tree-based models are better suited to capture compared to linear models.

# %% [markdown]
# While the model shows significant improvement, it faces the following constraints:Explainable Variance: An $R^{2}$ of 0.22 means there is still about 78% of price variation that the model cannot explain with the current features.Spatial Data: Price is heavily influenced by specific neighborhoods or proximity to landmarks, which are not fully captured in the current feature set.Market Volatility: The data represents a snapshot in time; it does not account for seasonal price spikes (e.g., holidays or local events).
